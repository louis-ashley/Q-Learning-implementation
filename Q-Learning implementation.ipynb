# %% [markdown]
# # Q-Learning implementation

# %% [markdown]
# In this Notebook is presented the implementation of a Q-Learning algorithm.
# It is the second part of a Reinforcement Learning serie.
#
# You can find the part one following this link :   https://www.kaggle.com/loulouashley/reinforcement-learning-basics-theory

# %% [markdown]
# ## Q-Learning Flowchart

# %% [markdown]
# The figure below describes the flowchart of the Q-Learning algorithm.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Q-Learning detail

# %% [markdown]
# The most important part in this flowchart is the Q-Table update, an update is done for each
# iteration.
#
#
# This update is done by the Q-Learning formula also called the bellman equation.
# An example of Q-update is shown.
#
#
# Only one cell of the table will be modified during the update, this cell corresponds to the
# couple &quot;current state, and action taken”.
#
#
# In the example represented by the figure below the current state is state 2 and the action is the
# action 2; the cell that will be modified by the update is the central cell (orange cell before
# update and green cell after update).It takes in consideration that this action will put the agent
# in the state 3.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The new value is defined by the Q-Learning formula:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In this example the following parameters are used:
#
# * 1-∝ = 0.5
# * ∝ = 0.5
# * gamma = 1
# * r = 10

# %% [markdown]
# Next equation shows the new equation obtained with these parameters:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3 elements are still to be defined:
#
# * Qn (St,At): it represents the new value of the cell in the Q-Table (green cell)
# * Q(St,At): it represents the old value of the cell in the Q-Table (orange cell)
# * MaxQ(St+1,A); it represents the highest value for the next state (grey cells)

# %% [markdown]
# By replacing these new elements in the formula; the value of the new cell is revealed

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Once the maximum number of iterations has been reached, the results can be extracted from the program.
# As seen in next figure, the main result is an example of a final Q-Table.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This Q-Table shows what is the best action to do for each state. An additional function gives for each state the action with the highest Q-Value, it transforms the Q-Table in a policy.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# I hope you enjoyed this Notebook, its the second one of a serie about Reinforcement Learning, the following episodes of this trhilling serie are comming soon ! Keep updated!
#
# Thank you!
